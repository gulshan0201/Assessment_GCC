# %%
# Read inputs
x = int(input())
y = int(input())
z = int(input())

# Rotate values
x, y, z = y, z, x

# Print output
print(x)
print(y)
print(z)
# Out:
# 3
# 4
# 2

# %%
# Read input
num = float(input())

# Get integral part
integer_part = int(num)

# Get right-most digit
right_most_digit = integer_part % 20

# Print output
print(right_most_digit)
# Out:
# 15

# %% [markdown]
# Write a program to read two numbers from the user and compute – 1st number to the power of the 2nd number.

# %%
a = float(input())
b = float(input())

result = a ** b

print(f"{result:.2f}")
# Out:
# 25.00

# %% [markdown]
# Write a program to find the square root of a given number and print the result.

# %%
num = float(input())

res = num ** 0.5

print(res)
# Out:
# 3.1622776601683795
