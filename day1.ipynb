# %%
# Read inputs
x = int(input())
y = int(input())
z = int(input())

# Rotate values
x, y, z = y, z, x

# Print output
print(x)
print(y)
print(z)
# Out:
# 3
# 4
# 2

# %%
# Read input
num = float(input())

# Get integral part
integer_part = int(num)

# Get right-most digit
right_most_digit = integer_part % 20

# Print output
print(right_most_digit)
# Out:
# 15
